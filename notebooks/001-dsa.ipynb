# %% [markdown]
# ## Getting digits from a number

# %%
def get_all_digits(number: int) -> None:
    """method to get all digits from the given number"""

    while number>0:
        last = number % 10
        print(last)
        number = number // 10

# %%
get_all_digits(5873)
# Out:
# 3
# 7
# 8
# 5

# %% [markdown]
# ## Counting the digits of a number

# %%
def count_all_digits(number: int) -> int:
    count = 0
    n = number
    while n>0:
        count+=1
        n=n//10
    return count

# %%
count_all_digits(5873)
# Out:
# 4

# %% [markdown]
# ## Reversing and checking the number is palindrome

# %%
def check_palindrome(number: int) -> int:
    """checks palindrome"""

    n = number
    result = 0
    while n > 0:
        last_digit = n%10
        result = result*10 + last_digit
        n = n//10
    return result

# %% [markdown]
# ## Armstrong Number

# %%
def is_armstrong_number(number: int) -> bool:
    """checks if number is armstrong"""

    num = number
    count = 0
    total_sum = 0
    while num > 0:
        count+=1
        num = num//10

    num = number
    while num > 0:
        digit = num%10
        total_sum += digit**count
        num=num//10

    return True if total_sum == number else False

# %%
is_armstrong_number(1634)
# Out:
# True

# %% [markdown]
# ## Count Frequency

# %%
import random
from typing import Sequence
random.seed(52)

elements = [random.randint(20, 100) for i in range(1,21)]
elements
# Out:
# [54,
#  26,
#  85,
#  81,
#  67,
#  72,
#  24,
#  37,
#  40,
#  72,
#  43,
#  64,
#  76,
#  100,
#  20,
#  24,
#  89,
#  69,
#  76,
#  21]

# %%
def count_frequency(seq: Sequence) -> dict:
    """count frequency"""

    frequency = {}
    for i in seq:
        if i not in frequency:
            frequency[i] = 1
        else:
            frequency[i] += 1
    return frequency

# %% [markdown]
# ## Hashing
